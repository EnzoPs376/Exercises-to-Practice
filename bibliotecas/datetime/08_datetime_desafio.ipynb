# %% [markdown]
# ## Calculando a idade
#
# Um usuário fornece sua data de nascimento no formato "dd/mm/aaaa". Crie um script Python que calcula a idade do usuário.

# %%
from datetime import datetime

data_nascimento_usuario = input("Informe sua data de nascimento (dd/mm/aaaa):")

# %%
nascimento_texto = datetime.strptime(data_nascimento_usuario, "%d/%m/%Y")
data_atual = datetime.now()
idade_usuario = data_atual.year - nascimento_texto.year

# %%
mes_atual = data_atual.month
dia_atual = data_atual.day

mes_nascimento = nascimento_texto.month
dia_nascimento = nascimento_texto.day

# %%
if mes_nascimento > mes_atual:
    idade_usuario -= 1
elif mes_nascimento == mes_atual and dia_nascimento > dia_atual:
    idade_usuario -= 1

print(idade_usuario)
# Out:
# 25
